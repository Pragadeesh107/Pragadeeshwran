# %% [markdown]
# ## EXP NO:7,DATE:25-2-2024,ROLL NO: 230901014

# %% [markdown]
# ## AIM

# %% [markdown]
# ## To implement the FIND-S algorithm and determine the most specific hypothesis from the given training dataset.

# %% [markdown]
# ## COMPONENTS REQUIRED:

# %% [markdown]
# ## To implement the FIND-S algorithm and determine the most specific hypothesis from the given training dataset.

# %% [markdown]
# ## Software: Jupyter Notebook (Anaconda 3)

# %%
# Define the FIND-S algorithm
def find_s_algorithm(examples):
    hypothesis = [None] * (len(examples[0]) - 1)
    
    for example in examples:
        if example[-1] == 'Yes':
            for i in range(len(hypothesis)):
                if hypothesis[i] is None:
                    hypothesis[i] = example[i]
                elif hypothesis[i] != example[i]:
                    hypothesis[i] = '?'
    
    return hypothesis

# Example training data
training_data = [
    ['Sunny', 'Warm', 'Normal', 'Strong', 'Warm', 'Same', 'Yes'],
    ['Sunny', 'Warm', 'High', 'Strong', 'Warm', 'Same', 'Yes'],
    ['Rainy', 'Cold', 'High', 'Strong', 'Warm', 'Change', 'No'],
    ['Sunny', 'Warm', 'High', 'Strong', 'Cool', 'Change', 'Yes']
]

# Run the FIND-S algorithm
hypothesis = find_s_algorithm(training_data)

# Print the hypothesis
print("The most specific hypothesis is:", hypothesis)
# Out:
# The most specific hypothesis is: ['Sunny', 'Warm', '?', 'Strong', '?', '?']

# %% [markdown]
# ## RESULT:

# %% [markdown]
# ## Thus the most specific hyothesis the determined by FIND-S algorithm
